# %% [markdown]
# # C/C++ Pipeline Overview
#
# This notebook documents the production-style Enron analytics flow implemented in C/C++:
#
# 1. Ingestion & normalization (`ingestion.c`)
# 2. Feature engineering (`feature_engineering.c`)
# 3. Dimensionality reduction (`pca.cpp`)
# 4. Modeling & scoring (`modeling.cpp`)
# 5. Validation summary (`validation.cpp`)

# %% [markdown]
# ## Production Inputs
# - `data/raw/enron/production_email_inputs.csv`
# - `data/raw/enron/production_financial_inputs.csv`
#
# ## Derived Outputs
# - `data/processed/production_feature_matrix.csv`
# - `data/curated/production_risk_profiles.csv`
